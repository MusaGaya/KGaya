# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/MusaGaya/KGaya/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
#
# Lane 2: Refresh / Content Opportunity Scoring
#
# I chose this lane because the starter pipeline already demonstrated
# that a learned model can meaningfully outperform a hand-written rule
# at identifying pages worth reviewing first. The random forest achieved
# a Precision@50 of 0.740 versus the baseline's 0.240 — roughly 3x better.
# This suggests there is real signal in the data worth building on.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# Question: Which pages should be reviewed first for content refresh?
#
# Decision: A content reviewer has limited time — they can only act on
# a small number of pages. This model helps them spend that time on the
# pages most likely to be declining.
#
# Action: Flag the top-K pages for human review and possible content update.
#
# Cost of a wrong call:
# - False positive: a reviewer wastes time on a page that did not need work.
# - False negative: a declining page is missed and continues to lose visibility.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*
#
# The starter dataset shows that 54.2% of pages are currently declining,
# a large pool that makes prioritization essential. Declining pages have a
# higher median impression count (961) than the dataset overall (731),
# suggesting these are not low-traffic pages but visible content worth acting on.
#
# The starter pipeline also showed that a random forest model achieved a
# Precision@50 of 0.740 versus the baseline's 0.240 — roughly 3x better —
# directionally supporting the case that learned signals can improve review prioritization.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import os, sys, subprocess

IN_COLAB = "google.colab" in sys.modules
REPO_URL = "https://github.com/flyrank-bih/flyrank-ml-internship-starter"
REPO_DIR = "flyrank-ml-internship-starter"

if IN_COLAB:
    if not os.path.isdir(REPO_DIR):
        subprocess.run(["git", "clone", "--depth", "1", REPO_URL, REPO_DIR], check=True)
    os.chdir(REPO_DIR)
import pandas as pd
import numpy as np

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

# How many pages are declining?
declining_rate = (df["trend_direction"] == "down").mean()
print(f"Declining pages: {declining_rate:.1%} of the dataset")

# How visible are declining pages?
declining = df[df["trend_direction"] == "down"]
print(f"Median impressions (declining): {declining['impressions_90d'].median():.0f}")
print(f"Median impressions (all): {df['impressions_90d'].median():.0f}")

# Baseline vs model
print(f"\nBaseline Precision@50: 0.240 (~12 of top 50 correct)")
print(f"Random Forest Precision@50: 0.740 (~37 of top 50 correct)")
print(f"Improvement: ~3x over the hand-written rule")
# Out:
# Declining pages: 54.2% of the dataset
# Median impressions (declining): 961
# Median impressions (all): 731
#
# Baseline Precision@50: 0.240 (~12 of top 50 correct)
# Random Forest Precision@50: 0.740 (~37 of top 50 correct)
# Improvement: ~3x over the hand-written rule

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*
#
# What I can claim (observed and directional):
# - In this 30,000-row starter dataset, a random forest model directionally
#   outperformed a hand-written baseline at ranking declining pages.
# - Observable signals such as impressions, content age, and CTR appear
#   associated with declining trend direction in this dataset.
#
# What I cannot claim:
# - That refreshing a flagged page will cause it to recover.
# - That these results generalize beyond this starter slice.
# - That I have identified Google algorithm factors.
# - All findings are observational, not causal.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
